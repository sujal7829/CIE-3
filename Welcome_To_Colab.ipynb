# %% [markdown]
# <a href="https://colab.research.google.com/github/sujal7829/CIE-3/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("student.csv")
df.head()
# Out:
#    slno   reg no   name  cie  see
# 0     1  23CS001   abhi   40   75
# 1     2  23CS002  akash   41   85
# 2     3  23CS003  anand   63   95
# 3     4  23CS004   anil   45   54
# 4     5  23CS005  sunil   46   65

# %%
x=df[['cie']]
y=df[['see']]
print(x)
print(y)
# Out:
#    cie
# 0   40
# 1   41
# 2   63
# 3   45
# 4   46
# 5   35
# 6   39
# 7   40
# 8   36
# 9   56
#    see
# 0   75
# 1   85
# 2   95
# 3   54
# 4   65
# 5   62
# 6   63
# 7   51
# 8   54
# 9   25

# %%
sns.scatterplot(x='cie',y='see',data=df)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#    cie
# 4   46
# 9   56
# 1   41
# 6   39
# 7   40
# 3   45
# 0   40
# 5   35

# %%
x_test
# Out:
#    cie
# 2   63
# 8   36

# %%
y_train
# Out:
#    see
# 4   65
# 9   25
# 1   85
# 6   63
# 7   51
# 3   54
# 0   75
# 5   62

# %%
y_test
# Out:
#    see
# 2   95
# 8   54

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
print("Training complete")
# Out:
# Training complete

# %%
df.isnull().sum()
# Out:
# slno      0
# reg no    0
# name      0
# cie       0
# see       0
# dtype: int64

# %%
df.ffill(inplace=True)
df.isnull().sum()
# Out:
# slno      0
# reg no    0
# name      0
# cie       0
# see       0
# dtype: int64
